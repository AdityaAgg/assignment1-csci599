# %% [markdown]
# # Problem 3: Training and Fine-tuning on Fashion MNIST and MNIST
# Training neural networks with a huge number of parameters on a small dataset greatly affects the networks' generalization ability, often resulting in overfitting. Therefore, more often in practice, one would fine-tune existing networks that are trained on a larger dataset by continuing training on a smaller dataset. To get familiar with the fine-tuning procedure, in this problem you need to train a model from scratch on Fashion MNIST dataset and then fine-tune it on MNIST dataset. Note that we are training models on these two toy datasets because of limited computational resources. In most cases, we train models on ImageNet and fine-tune them on smaller datasets.
#
# * <b>Learning Objective:</b> In Problem 2, you implemented a covolutional neural network to perform classification task in TensorFlow. In this part of the assignment, we will show you how to use TensorFlow to fine-tune a trained network on a different task.
# * <b>Provided Codes:</b> We provide the the dataset downloading and preprocessing codes, conv2d(), and fc() functions to build the model performing the fine-tuning task.
# * <b>TODOs:</b> Train a model from scratch on Fashion MNIST dataset and then fine-tune it on MNIST dataset. Both the training loss and the training accuracy need to be shown.

# %%
import numpy as np
import os.path as osp
import os
import subprocess

def download_data(download_root='data/', dataset='mnist'):
    if dataset == 'mnist':
        data_url = 'http://yann.lecun.com/exdb/mnist/'
    elif dataset == 'fashion_mnist':
        data_url = 'http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/'
    else:
        raise ValueError('Please specify mnist or fashion_mnist.')

    data_dir = osp.join(download_root, dataset)
    if osp.exists(data_dir):
        print('The dataset was downloaded.')
        return
    else:
        os.mkdir(data_dir)

    keys = ['train-images-idx3-ubyte.gz', 't10k-images-idx3-ubyte.gz',
            'train-labels-idx1-ubyte.gz', 't10k-labels-idx1-ubyte.gz']

    for k in keys:
        url = (data_url+k).format(**locals())
        target_path = osp.join(data_dir, k)
        cmd = ['curl', url, '-o', target_path]
        print('Downloading ', k)
        subprocess.call(cmd)
        cmd = ['gzip', '-d', target_path]
        print('Unzip ', k)
        subprocess.call(cmd)


def load_data(data_dir):
    num_train = 60000
    num_test = 10000

    def load_file(filename, num, shape):
        fd = open(osp.join(data_dir, filename))
        loaded = np.fromfile(file=fd, dtype=np.uint8)
        return loaded[num:].reshape(shape).astype(np.float)

    train_image = load_file('train-images-idx3-ubyte', 16, (num_train, 28, 28, 1))
    train_label = load_file('train-labels-idx1-ubyte', 8, num_train)
    test_image = load_file('t10k-images-idx3-ubyte', 16, (num_test, 28, 28, 1))
    test_label = load_file('t10k-labels-idx1-ubyte', 8, num_test)
    return train_image, train_label, test_image, test_label

# %%
# Download MNIST and Fashion MNIST
download_data(dataset='mnist')
download_data(dataset='fashion_mnist')
# Out:
# ('Downloading ', 'train-images-idx3-ubyte.gz')
# ('Unzip ', 'train-images-idx3-ubyte.gz')
# ('Downloading ', 't10k-images-idx3-ubyte.gz')
# ('Unzip ', 't10k-images-idx3-ubyte.gz')
# ('Downloading ', 'train-labels-idx1-ubyte.gz')
# ('Unzip ', 'train-labels-idx1-ubyte.gz')
# ('Downloading ', 't10k-labels-idx1-ubyte.gz')
# ('Unzip ', 't10k-labels-idx1-ubyte.gz')
# ('Downloading ', 'train-images-idx3-ubyte.gz')
# ('Unzip ', 'train-images-idx3-ubyte.gz')
# ('Downloading ', 't10k-images-idx3-ubyte.gz')
# ('Unzip ', 't10k-images-idx3-ubyte.gz')
# ('Downloading ', 'train-labels-idx1-ubyte.gz')
# ('Unzip ', 'train-labels-idx1-ubyte.gz')
# ('Downloading ', 't10k-labels-idx1-ubyte.gz')
# ('Unzip ', 't10k-labels-idx1-ubyte.gz')

# %%
import tensorflow as tf
import tensorflow.contrib.slim as slim
import matplotlib.pyplot as plt
# %matplotlib inline
tf.reset_default_graph()
def conv2d(input, output_shape, k=4, s=2, name='conv2d'):
    with tf.variable_scope(name):
        return slim.conv2d(input, output_shape, [k, k], stride=s)


def fc(input, output_shape, act_fn=tf.nn.relu, name='fc'):
    with tf.variable_scope(name):
        return slim.fully_connected(input, output_shape, activation_fn=act_fn)


def train(batch_size=100, num_epoch=5, learning_rate=1e-5,
          num_train=60000, num_test=10000):
    sess = tf.InteractiveSession()
    
    # Build the model
    X = tf.placeholder(tf.float32, [None, 28, 28, 1])
    Y = tf.placeholder(tf.int64, [None])
    labels = tf.one_hot(Y, 10)
    _ = conv2d(X, 32, name='convo1')
    _ = conv2d(_, 64, name='convo2')
    _ = conv2d(_, 256, name='convo3')
    _ = tf.reshape(_, [-1, np.prod(_.get_shape().as_list()[1:])])
    _ = fc(_, 256, name='fcc1')
    logits = fc(_, 10, act_fn=None, name='fcc2')

    loss = tf.nn.softmax_cross_entropy_with_logits(labels=labels, logits=logits)
    loss_op = tf.reduce_mean(loss)

    global_step = tf.Variable(0, trainable=False)
    learning_rate = 1e-4
    optimizer = tf.train.AdamOptimizer(learning_rate)
    train_op = optimizer.minimize(loss, global_step=global_step)

    predict = tf.argmax(logits, 1)
    correct = tf.equal(predict, Y)
    accuracy_op = tf.reduce_mean(tf.cast(correct, tf.float32))

    sess.run(tf.global_variables_initializer())

    total_loss = []
    total_accuracy = []

    print('\033[93mTrain Fashion MNIST\033[0m')
    X_train, Y_train, X_test, Y_test = load_data('data/fashion_mnist')
    #############################################################################
    # TODO: Train the model on Fashion MNIST from scratch                       #
    # and then fine-tune it on MNIST                                            #
    # Collect the training loss and the training accuracy                       #
    # fetched from each iteration                                               #
    # After the two stages of the training, the length of                       #
    # total_loss and total_accuracy shuold be                                   #
    # 2 *num_epoch * num_train / batch_size = 2 * 5 * 60000 / 100 = 6000        #
    #############################################################################
    # Train the model on Fashion MNIST
    step = 0
    for epoch in range(num_epoch):
        print('train for epoch %d' % epoch)
        for i in range(num_train // batch_size):
            X_ = X_train[i * batch_size:(i + 1) * batch_size][:]
            Y_ = Y_train[i * batch_size:(i + 1) * batch_size]

            #############################################################################
            # TODO: You can change feed data as you want                                #
            #############################################################################
            feed_dict = {X: X_, Y: Y_}                
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            fetches = [train_op, loss_op, accuracy_op]

            _, loss, accuracy = sess.run(fetches, feed_dict=feed_dict)
            total_loss.append(loss)
            total_accuracy.append(accuracy)

            if step % 50 == 0:
                print('iteration (%d): loss = %.3f, accuracy = %.3f' %
                    (step, loss, accuracy))
            step += 1
        print('[Epoch {}] loss: {}, accuracy: {}'.format(epoch, loss, accuracy))
    
    step = 0
    # Train the model on MNIST
    print('\033[93mTrain MNIST\033[0m')
    X_train, Y_train, X_test, Y_test = load_data('data/mnist')
    for epoch in range(num_epoch):
        for i in range(num_train // batch_size):
            X_ = X_train[i * batch_size:(i + 1) * batch_size][:]
            Y_ = Y_train[i * batch_size:(i + 1) * batch_size]

            #############################################################################
            # TODO: You can change feed data as you want                                #
            #############################################################################
            feed_dict = {X: X_, Y: Y_}                
            #############################################################################
            #                             END OF YOUR CODE                              #
            #############################################################################
            fetches = [train_op, loss_op, accuracy_op]

            _, loss, accuracy = sess.run(fetches, feed_dict=feed_dict)
            total_loss.append(loss)
            total_accuracy.append(accuracy)

            if step % 50 == 0:
                print('iteration (%d): loss = %.3f, accuracy = %.3f' %
                    (step, loss, accuracy))
            step += 1
        print('[Epoch {}] loss: {}, accuracy: {}'.format(epoch, loss, accuracy))

    #############################################################################
    #                             END OF YOUR CODE                              #
    #############################################################################
    return total_loss, total_accuracy

# %%
loss, accuracy = train()
# Out:
# Train Fashion MNIST
# train for epoch 0
# iteration (0): loss = 11.414, accuracy = 0.070
# iteration (50): loss = 0.808, accuracy = 0.760
# iteration (100): loss = 0.487, accuracy = 0.850
# iteration (150): loss = 0.523, accuracy = 0.850
# iteration (200): loss = 0.425, accuracy = 0.870
# iteration (250): loss = 0.323, accuracy = 0.910
# iteration (300): loss = 0.530, accuracy = 0.810
# iteration (350): loss = 0.316, accuracy = 0.880
# iteration (400): loss = 0.551, accuracy = 0.790
# iteration (450): loss = 0.424, accuracy = 0.860
# iteration (500): loss = 0.575, accuracy = 0.840
# iteration (550): loss = 0.409, accuracy = 0.820
# [Epoch 0] loss: 0.340597391129, accuracy: 0.860000014305
# train for epoch 1
# iteration (600): loss = 0.260, accuracy = 0.910
# iteration (650): loss = 0.432, accuracy = 0.810
# iteration (700): loss = 0.341, accuracy = 0.870
# iteration (750): loss = 0.328, accuracy = 0.870
# iteration (800): loss = 0.278, accuracy = 0.880
# iteration (850): loss = 0.206, accuracy = 0.920
# iteration (900): loss = 0.405, accuracy = 0.850
# iteration (950): loss = 0.282, accuracy = 0.890
# iteration (1000): loss = 0.493, accuracy = 0.810
# iteration (1050): loss = 0.284, accuracy = 0.890
# iteration (1100): loss = 0.424, accuracy = 0.870
# iteration (1150): loss = 0.315, accuracy = 0.860
# [Epoch 1] loss: 0.274037718773, accuracy: 0.879999995232
# train for epoch 2
# iteration (1200): loss = 0.219, accuracy = 0.930
# iteration (1250): loss = 0.328, accuracy = 0.870
# iteration (1300): loss = 0.256, accuracy = 0.940
# iteration (1350): loss = 0.247, accuracy = 0.890
# iteration (1400): loss = 0.236, accuracy = 0.900
# iteration (1450): loss = 0.169, accuracy = 0.930
# iteration (1500): loss = 0.274, accuracy = 0.910
# iteration (1550): loss = 0.216, accuracy = 0.910
# iteration (1600): loss = 0.469, accuracy = 0.830
# iteration (1650): loss = 0.217, accuracy = 0.910
# iteration (1700): loss = 0.315, accuracy = 0.860
# iteration (1750): loss = 0.262, accuracy = 0.890
# [Epoch 2] loss: 0.222849041224, accuracy: 0.939999997616
# train for epoch 3
# iteration (1800): loss = 0.171, accuracy = 0.950
# iteration (1850): loss = 0.247, accuracy = 0.910
# iteration (1900): loss = 0.237, accuracy = 0.930
# iteration (1950): loss = 0.199, accuracy = 0.920
# iteration (2000): loss = 0.198, accuracy = 0.910
# iteration (2050): loss = 0.153, accuracy = 0.930
# iteration (2100): loss = 0.214, accuracy = 0.910
# iteration (2150): loss = 0.156, accuracy = 0.940
# iteration (2200): loss = 0.385, accuracy = 0.860
# iteration (2250): loss = 0.178, accuracy = 0.910
# iteration (2300): loss = 0.234, accuracy = 0.890
# iteration (2350): loss = 0.231, accuracy = 0.930
# [Epoch 3] loss: 0.167812079191, accuracy: 0.939999997616
# train for epoch 4
# iteration (2400): loss = 0.131, accuracy = 0.970
# iteration (2450): loss = 0.185, accuracy = 0.920
# iteration (2500): loss = 0.159, accuracy = 0.950
# iteration (2550): loss = 0.170, accuracy = 0.940
# iteration (2600): loss = 0.164, accuracy = 0.950
# iteration (2650): loss = 0.130, accuracy = 0.940
# iteration (2700): loss = 0.189, accuracy = 0.910
# iteration (2750): loss = 0.118, accuracy = 0.960
# iteration (2800): loss = 0.314, accuracy = 0.890
# iteration (2850): loss = 0.158, accuracy = 0.930
# iteration (2900): loss = 0.180, accuracy = 0.970
# iteration (2950): loss = 0.199, accuracy = 0.930
# [Epoch 4] loss: 0.145389929414, accuracy: 0.959999978542
# Train MNIST
# iteration (0): loss = 6.715, accuracy = 0.120
# iteration (50): loss = 0.196, accuracy = 0.940
# iteration (100): loss = 0.181, accuracy = 0.960
# iteration (150): loss = 0.101, accuracy = 0.970
# iteration (200): loss = 0.234, accuracy = 0.920
# iteration (250): loss = 0.057, accuracy = 0.980
# iteration (300): loss = 0.220, accuracy = 0.950
# iteration (350): loss = 0.088, accuracy = 0.970
# iteration (400): loss = 0.086, accuracy = 0.980
# iteration (450): loss = 0.074, accuracy = 0.970
# iteration (500): loss = 0.034, accuracy = 1.000
# iteration (550): loss = 0.040, accuracy = 0.990
# [Epoch 0] loss: 0.254740893841, accuracy: 0.990000009537
# iteration (600): loss = 0.064, accuracy = 0.980
# iteration (650): loss = 0.057, accuracy = 0.970
# iteration (700): loss = 0.056, accuracy = 0.980
# iteration (750): loss = 0.029, accuracy = 0.990
# iteration (800): loss = 0.046, accuracy = 0.990
# iteration (850): loss = 0.009, accuracy = 1.000
# iteration (900): loss = 0.119, accuracy = 0.980
# iteration (950): loss = 0.051, accuracy = 0.980
# iteration (1000): loss = 0.037, accuracy = 0.990
# iteration (1050): loss = 0.019, accuracy = 1.000
# iteration (1100): loss = 0.014, accuracy = 1.000
# iteration (1150): loss = 0.011, accuracy = 1.000
# [Epoch 1] loss: 0.229104503989, accuracy: 0.990000009537
# iteration (1200): loss = 0.038, accuracy = 0.980
# iteration (1250): loss = 0.023, accuracy = 1.000
# iteration (1300): loss = 0.020, accuracy = 1.000
# iteration (1350): loss = 0.013, accuracy = 1.000
# iteration (1400): loss = 0.017, accuracy = 0.990
# iteration (1450): loss = 0.003, accuracy = 1.000
# iteration (1500): loss = 0.070, accuracy = 0.990
# iteration (1550): loss = 0.017, accuracy = 0.990
# iteration (1600): loss = 0.013, accuracy = 1.000
# iteration (1650): loss = 0.008, accuracy = 1.000
# iteration (1700): loss = 0.006, accuracy = 1.000
# iteration (1750): loss = 0.003, accuracy = 1.000
# [Epoch 2] loss: 0.216765359044, accuracy: 0.990000009537
# iteration (1800): loss = 0.012, accuracy = 1.000
# iteration (1850): loss = 0.010, accuracy = 1.000
# iteration (1900): loss = 0.007, accuracy = 1.000
# iteration (1950): loss = 0.007, accuracy = 1.000
# iteration (2000): loss = 0.012, accuracy = 1.000
# iteration (2050): loss = 0.002, accuracy = 1.000
# iteration (2100): loss = 0.016, accuracy = 0.990
# iteration (2150): loss = 0.007, accuracy = 1.000
# iteration (2200): loss = 0.006, accuracy = 1.000
# iteration (2250): loss = 0.007, accuracy = 1.000
# iteration (2300): loss = 0.002, accuracy = 1.000
# iteration (2350): loss = 0.001, accuracy = 1.000
# [Epoch 3] loss: 0.208259373903, accuracy: 0.990000009537
# iteration (2400): loss = 0.003, accuracy = 1.000
# iteration (2450): loss = 0.004, accuracy = 1.000
# iteration (2500): loss = 0.002, accuracy = 1.000
# iteration (2550): loss = 0.003, accuracy = 1.000
# iteration (2600): loss = 0.013, accuracy = 0.990
# iteration (2650): loss = 0.001, accuracy = 1.000
# iteration (2700): loss = 0.005, accuracy = 1.000
# iteration (2750): loss = 0.001, accuracy = 1.000
# iteration (2800): loss = 0.004, accuracy = 1.000
# iteration (2850): loss = 0.003, accuracy = 1.000
# iteration (2900): loss = 0.002, accuracy = 1.000
# iteration (2950): loss = 0.005, accuracy = 1.000
# [Epoch 4] loss: 0.162253320217, accuracy: 0.990000009537

# %%
# Plot the training loss and the training accuracy
plt.plot(loss)
plt.title('training loss')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.show()    

plt.plot(accuracy)
plt.title('training accuracy')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.show()
